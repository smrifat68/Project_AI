# %% [markdown]
# ## Environment Setup & Library Installation

# %%
# !pip uninstall googletrans httpx -y
# !pip install --upgrade gradio
# !pip install deep-translator gradio
# Out:
# Found existing installation: httpx 0.28.1
# Uninstalling httpx-0.28.1:
#   Successfully uninstalled httpx-0.28.1
# WARNING: Skipping googletrans as it is not installed.
# Requirement already satisfied: gradio in d:\anaconda\lib\site-packages (6.14.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in d:\anaconda\lib\site-packages (from gradio) (4.13.0)
# Requirement already satisfied: brotli>=1.1.0 in d:\anaconda\lib\site-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in d:\anaconda\lib\site-packages (from gradio) (0.136.1)
# Requirement already satisfied: gradio-client==2.5.0 in d:\anaconda\lib\site-packages (from gradio) (2.5.0)
# Requirement already satisfied: groovy~=0.1 in d:\anaconda\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: hf-gradio<1.0,>=0.4.1 in d:\anaconda\lib\site-packages (from gradio) (0.4.1)
# Collecting httpx<1.0,>=0.24.1 (from gradio)
#   Obtaining dependency information for httpx<1.0,>=0.24.1 from https://files.pythonhosted.org/packages/2a/39/e50c7c3a983047577ee07d2a9e53faf5a69493943ec3f6a384bdc792deb2/httpx-0.28.1-py3-none-any.whl.metadata
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in d:\anaconda\lib\site-packages (from gradio) (0.36.2)
# Requirement already satisfied: jinja2<4.0 in d:\anaconda\lib\site-packages (from gradio) (3.1.2)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in d:\anaconda\lib\site-packages (from gradio) (2.1.1)
# Requirement already satisfied: numpy<3.0,>=1.0 in d:\anaconda\lib\site-packages (from gradio) (1.24.3)
# Requirement already satisfied: orjson~=3.0 in d:\anaconda\lib\site-packages (from gradio) (3.11.9)
# Requirement already satisfied: packaging in d:\anaconda\lib\site-packages (from gradio) (23.1)
# Requirement already satisfied: pandas<4.0,>=1.0 in d:\anaconda\lib\site-packages (from gradio) (2.0.3)
# Requirement already satisfied: pillow<13.0,>=8.0 in d:\anaconda\lib\site-packages (from gradio) (9.4.0)
# Requirement already satisfied: pydantic<=3.0,>=2.0 in d:\anaconda\lib\site-packages (from gradio) (2.13.4)
# Requirement already satisfied: pydub<1.0 in d:\anaconda\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart<1.0,>=0.0.18 in d:\anaconda\lib\site-packages (from gradio) (0.0.28)
# Requirement already satisfied: pytz>=2017.2 in d:\anaconda\lib\site-packages (from gradio) (2023.3.post1)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in d:\anaconda\lib\site-packages (from gradio) (6.0)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.7 in d:\anaconda\lib\site-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in d:\anaconda\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<2.0,>=0.40.0 in d:\anaconda\lib\site-packages (from gradio) (1.0.0)
# Requirement already satisfied: tomlkit<0.15.0,>=0.12.0 in d:\anaconda\lib\site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in d:\anaconda\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: typing-extensions~=4.0 in d:\anaconda\lib\site-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in d:\anaconda\lib\site-packages (from gradio) (0.46.0)
# Requirement already satisfied: fsspec in d:\anaconda\lib\site-packages (from gradio-client==2.5.0->gradio) (2026.4.0)
# Requirement already satisfied: idna>=2.8 in d:\anaconda\lib\site-packages (from anyio<5.0,>=3.0->gradio) (2.10)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\anaconda\lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in d:\anaconda\lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: certifi in d:\anaconda\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in d:\anaconda\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\anaconda\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in d:\anaconda\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.9.0)
# Requirement already satisfied: requests in d:\anaconda\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in d:\anaconda\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.65.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\lib\site-packages (from pandas<4.0,>=1.0->gradio) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in d:\anaconda\lib\site-packages (from pandas<4.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\anaconda\lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in d:\anaconda\lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (2.46.4)
# Requirement already satisfied: click>=8.2.1 in d:\anaconda\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in d:\anaconda\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in d:\anaconda\lib\site-packages (from typer<1.0,>=0.12->gradio) (15.0.0)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from click>=8.2.1->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\anaconda\lib\site-packages (from rich>=13.8.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\anaconda\lib\site-packages (from rich>=13.8.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests->huggingface-hub<2.0,>=0.33.5->gradio) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests->huggingface-hub<2.0,>=0.33.5->gradio) (1.26.16)
# Requirement already satisfied: mdurl~=0.1 in d:\anaconda\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0,>=0.12->gradio) (0.1.0)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Installing collected packages: httpx
# Successfully installed httpx-0.28.1
# Requirement already satisfied: deep-translator in d:\anaconda\lib\site-packages (1.11.4)
# Requirement already satisfied: gradio in d:\anaconda\lib\site-packages (6.14.0)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in d:\anaconda\lib\site-packages (from deep-translator) (4.12.2)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in d:\anaconda\lib\site-packages (from deep-translator) (2.31.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in d:\anaconda\lib\site-packages (from gradio) (4.13.0)
# Requirement already satisfied: brotli>=1.1.0 in d:\anaconda\lib\site-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in d:\anaconda\lib\site-packages (from gradio) (0.136.1)
# Requirement already satisfied: gradio-client==2.5.0 in d:\anaconda\lib\site-packages (from gradio) (2.5.0)
# Requirement already satisfied: groovy~=0.1 in d:\anaconda\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: hf-gradio<1.0,>=0.4.1 in d:\anaconda\lib\site-packages (from gradio) (0.4.1)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in d:\anaconda\lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in d:\anaconda\lib\site-packages (from gradio) (0.36.2)
# Requirement already satisfied: jinja2<4.0 in d:\anaconda\lib\site-packages (from gradio) (3.1.2)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in d:\anaconda\lib\site-packages (from gradio) (2.1.1)
# Requirement already satisfied: numpy<3.0,>=1.0 in d:\anaconda\lib\site-packages (from gradio) (1.24.3)
# Requirement already satisfied: orjson~=3.0 in d:\anaconda\lib\site-packages (from gradio) (3.11.9)
# Requirement already satisfied: packaging in d:\anaconda\lib\site-packages (from gradio) (23.1)
# Requirement already satisfied: pandas<4.0,>=1.0 in d:\anaconda\lib\site-packages (from gradio) (2.0.3)
# Requirement already satisfied: pillow<13.0,>=8.0 in d:\anaconda\lib\site-packages (from gradio) (9.4.0)
# Requirement already satisfied: pydantic<=3.0,>=2.0 in d:\anaconda\lib\site-packages (from gradio) (2.13.4)
# Requirement already satisfied: pydub<1.0 in d:\anaconda\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart<1.0,>=0.0.18 in d:\anaconda\lib\site-packages (from gradio) (0.0.28)
# Requirement already satisfied: pytz>=2017.2 in d:\anaconda\lib\site-packages (from gradio) (2023.3.post1)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in d:\anaconda\lib\site-packages (from gradio) (6.0)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.7 in d:\anaconda\lib\site-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in d:\anaconda\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<2.0,>=0.40.0 in d:\anaconda\lib\site-packages (from gradio) (1.0.0)
# Requirement already satisfied: tomlkit<0.15.0,>=0.12.0 in d:\anaconda\lib\site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in d:\anaconda\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: typing-extensions~=4.0 in d:\anaconda\lib\site-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in d:\anaconda\lib\site-packages (from gradio) (0.46.0)
# Requirement already satisfied: fsspec in d:\anaconda\lib\site-packages (from gradio-client==2.5.0->gradio) (2026.4.0)
# Requirement already satisfied: idna>=2.8 in d:\anaconda\lib\site-packages (from anyio<5.0,>=3.0->gradio) (2.10)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda\lib\site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\anaconda\lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in d:\anaconda\lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: certifi in d:\anaconda\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in d:\anaconda\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\anaconda\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in d:\anaconda\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.9.0)
# Requirement already satisfied: tqdm>=4.42.1 in d:\anaconda\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.65.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\lib\site-packages (from pandas<4.0,>=1.0->gradio) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in d:\anaconda\lib\site-packages (from pandas<4.0,>=1.0->gradio) (2023.3)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\anaconda\lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in d:\anaconda\lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (2.46.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (1.26.16)
# Requirement already satisfied: click>=8.2.1 in d:\anaconda\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in d:\anaconda\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in d:\anaconda\lib\site-packages (from typer<1.0,>=0.12->gradio) (15.0.0)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from click>=8.2.1->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\anaconda\lib\site-packages (from rich>=13.8.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\anaconda\lib\site-packages (from rich>=13.8.0->typer<1.0,>=0.12->gradio) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in d:\anaconda\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<1.0,>=0.12->gradio) (0.1.0)

# %% [markdown]
# ## Import Libraries and Dependencies

# %%
import gradio as gr
from deep_translator import GoogleTranslator

# %% [markdown]
# ## Fetching and Sorting Supported Languages

# %%
SUPPORTED_LANGUAGES = GoogleTranslator(source="auto", target="en").get_supported_languages(as_dict=True)
all_languages = sorted([name.capitalize() for name in SUPPORTED_LANGUAGES.keys()])

# %% [markdown]
# ## Debug: View Language Dictionary

# %%
print(SUPPORTED_LANGUAGES)
# Out:
# {'afrikaans': 'af', 'albanian': 'sq', 'amharic': 'am', 'arabic': 'ar', 'armenian': 'hy', 'assamese': 'as', 'aymara': 'ay', 'azerbaijani': 'az', 'bambara': 'bm', 'basque': 'eu', 'belarusian': 'be', 'bengali': 'bn', 'bhojpuri': 'bho', 'bosnian': 'bs', 'bulgarian': 'bg', 'catalan': 'ca', 'cebuano': 'ceb', 'chichewa': 'ny', 'chinese (simplified)': 'zh-CN', 'chinese (traditional)': 'zh-TW', 'corsican': 'co', 'croatian': 'hr', 'czech': 'cs', 'danish': 'da', 'dhivehi': 'dv', 'dogri': 'doi', 'dutch': 'nl', 'english': 'en', 'esperanto': 'eo', 'estonian': 'et', 'ewe': 'ee', 'filipino': 'tl', 'finnish': 'fi', 'french': 'fr', 'frisian': 'fy', 'galician': 'gl', 'georgian': 'ka', 'german': 'de', 'greek': 'el', 'guarani': 'gn', 'gujarati': 'gu', 'haitian creole': 'ht', 'hausa': 'ha', 'hawaiian': 'haw', 'hebrew': 'iw', 'hindi': 'hi', 'hmong': 'hmn', 'hungarian': 'hu', 'icelandic': 'is', 'igbo': 'ig', 'ilocano': 'ilo', 'indonesian': 'id', 'irish': 'ga', 'italian': 'it', 'japanese': 'ja', 'javanese': 'jw', 'kannada': 'kn', 'kazakh': 'kk', 'khmer': 'km', 'kinyarwanda': 'rw', 'konkani': 'gom', 'korean': 'ko', 'krio': 'kri', 'kurdish (kurmanji)': 'ku', 'kurdish (sorani)': 'ckb', 'kyrgyz': 'ky', 'lao': 'lo', 'latin': 'la', 'latvian': 'lv', 'lingala': 'ln', 'lithuanian': 'lt', 'luganda': 'lg', 'luxembourgish': 'lb', 'macedonian': 'mk', 'maithili': 'mai', 'malagasy': 'mg', 'malay': 'ms', 'malayalam': 'ml', 'maltese': 'mt', 'maori': 'mi', 'marathi': 'mr', 'meiteilon (manipuri)': 'mni-Mtei', 'mizo': 'lus', 'mongolian': 'mn', 'myanmar': 'my', 'nepali': 'ne', 'norwegian': 'no', 'odia (oriya)': 'or', 'oromo': 'om', 'pashto': 'ps', 'persian': 'fa', 'polish': 'pl', 'portuguese': 'pt', 'punjabi': 'pa', 'quechua': 'qu', 'romanian': 'ro', 'russian': 'ru', 'samoan': 'sm', 'sanskrit': 'sa', 'scots gaelic': 'gd', 'sepedi': 'nso', 'serbian': 'sr', 'sesotho': 'st', 'shona': 'sn', 'sindhi': 'sd', 'sinhala': 'si', 'slovak': 'sk', 'slovenian': 'sl', 'somali': 'so', 'spanish': 'es', 'sundanese': 'su', 'swahili': 'sw', 'swedish': 'sv', 'tajik': 'tg', 'tamil': 'ta', 'tatar': 'tt', 'telugu': 'te', 'thai': 'th', 'tigrinya': 'ti', 'tsonga': 'ts', 'turkish': 'tr', 'turkmen': 'tk', 'twi': 'ak', 'ukrainian': 'uk', 'urdu': 'ur', 'uyghur': 'ug', 'uzbek': 'uz', 'vietnamese': 'vi', 'welsh': 'cy', 'xhosa': 'xh', 'yiddish': 'yi', 'yoruba': 'yo', 'zulu': 'zu'}

# %% [markdown]
# ## View Sorting Supported Languages

# %%
print(all_languages)
# Out:
# ['Afrikaans', 'Albanian', 'Amharic', 'Arabic', 'Armenian', 'Assamese', 'Aymara', 'Azerbaijani', 'Bambara', 'Basque', 'Belarusian', 'Bengali', 'Bhojpuri', 'Bosnian', 'Bulgarian', 'Catalan', 'Cebuano', 'Chichewa', 'Chinese (simplified)', 'Chinese (traditional)', 'Corsican', 'Croatian', 'Czech', 'Danish', 'Dhivehi', 'Dogri', 'Dutch', 'English', 'Esperanto', 'Estonian', 'Ewe', 'Filipino', 'Finnish', 'French', 'Frisian', 'Galician', 'Georgian', 'German', 'Greek', 'Guarani', 'Gujarati', 'Haitian creole', 'Hausa', 'Hawaiian', 'Hebrew', 'Hindi', 'Hmong', 'Hungarian', 'Icelandic', 'Igbo', 'Ilocano', 'Indonesian', 'Irish', 'Italian', 'Japanese', 'Javanese', 'Kannada', 'Kazakh', 'Khmer', 'Kinyarwanda', 'Konkani', 'Korean', 'Krio', 'Kurdish (kurmanji)', 'Kurdish (sorani)', 'Kyrgyz', 'Lao', 'Latin', 'Latvian', 'Lingala', 'Lithuanian', 'Luganda', 'Luxembourgish', 'Macedonian', 'Maithili', 'Malagasy', 'Malay', 'Malayalam', 'Maltese', 'Maori', 'Marathi', 'Meiteilon (manipuri)', 'Mizo', 'Mongolian', 'Myanmar', 'Nepali', 'Norwegian', 'Odia (oriya)', 'Oromo', 'Pashto', 'Persian', 'Polish', 'Portuguese', 'Punjabi', 'Quechua', 'Romanian', 'Russian', 'Samoan', 'Sanskrit', 'Scots gaelic', 'Sepedi', 'Serbian', 'Sesotho', 'Shona', 'Sindhi', 'Sinhala', 'Slovak', 'Slovenian', 'Somali', 'Spanish', 'Sundanese', 'Swahili', 'Swedish', 'Tajik', 'Tamil', 'Tatar', 'Telugu', 'Thai', 'Tigrinya', 'Tsonga', 'Turkish', 'Turkmen', 'Twi', 'Ukrainian', 'Urdu', 'Uyghur', 'Uzbek', 'Vietnamese', 'Welsh', 'Xhosa', 'Yiddish', 'Yoruba', 'Zulu']

# %% [markdown]
# ## Defining the Translation Logical Function

# %%
def perform_translation(text: str, target_lang: str) -> str:
    #Translate input text into the chosen target language.
    if not text.strip():
        return " Please enter some text to translate."
    try:
        target_key = target_lang.lower()
        translated = GoogleTranslator(source="auto", target=target_key).translate(text)
        return translated
    except Exception as e:
        return f"Translation Error: {str(e)}"

# %% [markdown]
# ## Testing the Translation Function

# %%
print(perform_translation('ਮੈਂ ਇਨਸਾਨ ਹਾਂ','english'))
# Out:
# I am human

# %% [markdown]
# ## Building the Gradio User Interface (UI)

# %%
with gr.Blocks() as demo:

    gr.Markdown("  AI Universal Translator")
    gr.Markdown("Enter text and select a target language — translation is instant.")

    with gr.Row():

        with gr.Column():
            input_box = gr.Textbox(
                label="Source Text",
                placeholder="Type or paste text here…",
                lines=7,
            )
            lang_dropdown = gr.Dropdown(
                choices=all_languages,
                label="Target Language",
                value="Bengali",
                filterable=True,
            )
            submit_btn = gr.Button("Translate", variant="primary")

        with gr.Column():
            # show_copy_button removed in Gradio 6.0 — use a separate button
            output_box = gr.Textbox(
                label="Translated Result",
                lines=7,
                interactive=False,
            )
            copy_btn = gr.Button("Copy to Clipboard")

    # Translate on button click
    submit_btn.click(
        fn=perform_translation,
        inputs=[input_box, lang_dropdown],
        outputs=output_box,
    )

    # Also translate on Enter key
    input_box.submit(
        fn=perform_translation,
        inputs=[input_box, lang_dropdown],
        outputs=output_box,
    )

    # Copy to clipboard via JavaScript
    copy_btn.click(
        fn=None,
        inputs=output_box,
        js="(text) => { navigator.clipboard.writeText(text); alert('Copied!'); }"
    )

# %% [markdown]
# ## Launching the Gradio Server

# %%
demo.launch(theme=gr.themes.Soft())
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
